# %% [markdown]
# # Grupo 7 Antes de empezar:
# - Lee el archivo README.md
# - Comenta todo lo que puedas y utiliza los recursos en el archivo README.md
# - ¡Feliz aprendizaje!

# %%
# Import reduce from functools, numpy and pandas
from functools import reduce
import numpy
import pandas

# %% [markdown]
# # Desafío 1 - Mapping
#
# #### Usaremos la función map para limpiar palabras en un libro.
#
# En la siguiente celda, leeremos un archivo de texto que contiene el libro El Profeta de Khalil Gibran.

# %%
# Corre este codigo:

location = 'data/58585-0.txt'
with open(location, 'r', encoding="utf8") as f:
    prophet = f.read().split(' ')

# %%
len(prophet)
# Out:
# 13637

# %% [markdown]
# #### Vamos a eliminar las primeras 568 palabras ya que contienen información sobre el libro pero no son parte del libro en sí.
#
# Haz esto eliminando de `prophet` los elementos del 0 al 567 de la lista (también puedes hacer esto manteniendo los elementos del 568 al último elemento).

# %%
# tu codigo aquí
prophet_recortado=prophet[568:]

print(len(prophet_recortado))
print(len(prophet)-len(prophet_recortado))
# Out:
# 13069
# 568

# %% [markdown]
# Si revisas las palabras, encontrarás que muchas palabras tienen una referencia adjunta a ellas. Por ejemplo, veamos las palabras del 1 al 10.

# %%
# tu codigo aquí
ejemplo_list=prophet_recortado[0:10]
print(len(ejemplo_list))
print(ejemplo_list)
# Out:
# 10
# ['PROPHET\n\n|Almustafa,', 'the{7}', 'chosen', 'and', 'the\nbeloved,', 'who', 'was', 'a', 'dawn', 'unto']

# %% [markdown]
# #### El siguiente paso es crear una función que eliminará las referencias.
#
# Haremos esto dividiendo la cadena en el carácter `{` y manteniendo solo la parte antes de este carácter. Escribe tu función a continuación.

# %%
def referencia(x):
    '''
    Entrada: Una cadena
    Salida: La cadena con las referencias eliminadas
    
    Ejemplo:
    Entrada: 'the{7}'
    Salida: 'the'
    '''
    
    # tu código aquí
    return x[:x.find("{")]

# %% [markdown]
# Ahora que tenemos nuestra función, usa la función `map()` para aplicar esta función a nuestro libro, El Profeta. Devuelve la lista resultante a una nueva lista llamada `prophet_reference`.

# %%
# tu codigo aquí
prophet_reference=list(map(referencia,prophet_recortado))

# %% [markdown]
# Otra cosa que podrías haber notado es que algunas palabras contienen un salto de línea. Escribamos una función para dividir esas palabras. Nuestra función devolverá la cadena dividida en el carácter `\n`. Escribe tu función en la celda de abajo.

# %%
def salto_de_linea(x):
    '''
    Entrada: Una cadena
    Salida: Una lista de cadenas divididas en el carácter de salto de línea (\n)
        
    Ejemplo:
    Entrada: 'the\nbeloved'
    Salida: ['the', 'beloved']
    '''
    
    # tu código aquí
    return x.split("\n")

# %% [markdown]
# Aplica la función `salto_de_linea` a la lista `prophet_reference`. Nombra la nueva lista `prophet_line`.

# %%
# tu codigo aquí
prophet_line=list(map(salto_de_linea,prophet_reference))

# %% [markdown]
# Si miras los elementos de `prophet_line`, verás que la función devolvió listas y no cadenas. Nuestra lista ahora es una lista de listas. Aplana la lista usando comprensión de listas. Asigna esta nueva lista a `prophet_flat`.

# %%
# tu codigo aquí
prophet_flat = [i for sub in prophet_line for i in sub]
prophet_flat

# %% [markdown]
# # Desafío 2 - Filtering
#
# Al imprimir algunas palabras del libro, vemos que hay palabras que tal vez no queramos conservar si elegimos analizar el corpus de texto. A continuación, se muestra una lista de palabras que nos gustaría eliminar. Crea una función que devuelva falso si contiene una palabra de la lista de palabras especificadas y verdadero de lo contrario.

# %%
def filtro_palabra(x):
    '''
    Entrada: Una cadena
    Salida: Verdadero si la palabra no está en la lista especificada 
    y Falso si la palabra está en la lista.
        
    Ejemplo:
    lista de palabras = ['and', 'the']
    Entrada: 'and'
    Salida: FALSE
    
    Entrada: 'John'
    Salida: TRUE
    '''
    
    lista_palabras = ['and', 'the', 'a', 'an']
    
    # tu código aquí
    if x.lower() in lista_palabras:
        return False
    else:
        return True

# %% [markdown]
# Usa la función `filter()` para filtrar las palabras especificadas en la función `filtro_palabra()`. Guarda la lista filtrada en la variable `prophet_filter`.

# %%
# tu codigo aquí
prophet_filter=list(filter(filtro_palabra,prophet_flat))
print(prophet_filter)
# Out:
# ['PROPHET', '', '|Almustafa', 'chose', 'beloved', 'wh', 'wa', '', 'daw', 'unt', 'hi', 'own', 'day', 'ha', 'waite', 'twelv', 'year', 'i', 'th', 'city', 'o', 'Orphales', 'fo', 'hi', 'shi', 'tha', 'wa', 'to', 'retur', 'bea', 'hi', 'bac', 't', 'th', 'isl', 'of', 'hi', 'birth.', '', 'i', 'th', 'twelft', 'year', 'o', 'th', 'seventh', 'da', 'o', 'Ielool', 'th', 'mont', 'o', 'reaping', 'he', 'climbe', 'th', 'hil', 'withou', 'th', 'cit', 'walls', 'looke', 'seaward', 'h', 'behel', 'his', 'shi', 'comin', 'wit', 'th', 'mist.', '', 'th', 'gate', 'o', 'hi', 'hear', 'wer', 'flung', 'open', 'hi', 'jo', 'fle', 'fa', 'ove', 'th', 'sea.', 'h', 'close', 'hi', 'eye', 'praye', 'i', 'silence', 'o', 'hi', 'soul.', '', '*****', '', 'Bu', 'h', 'descende', 'th', 'hill', '', 'sadness', 'cam', 'upo', 'him', 'h', 'though', 'i', 'his', 'heart:', '', 'Ho', 'shal', '', 'g', 'i', 'peac', 'without', 'sorrow', 'Nay', 'no', 'withou', '', 'woun', 'i', 'spiri', 'shal', '', 'leav', 'thi', 'city', '', 'th', 'day', 'o', 'pai', '', 'hav', 'spent', 'withi', 'it', 'walls', 'lon', 'wer', 'night', 'o', 'aloneness', 'wh', 'ca', 'depart', 'fro', 'hi', 'pai', 'hi', 'alonenes', 'without', 'regret?', '', 'To', 'man', 'fragment', 'o', 'th', 'spiri', 'hav', 'I', 'scattere', 'i', 'thes', 'streets', 'to', 'many', 'ar', 'th', 'childre', 'o', 'm', 'longin', 'tha', 'walk', 'nake', 'amon', 'thes', 'hills', '', 'cannot', 'withdra', 'fro', 'withou', '', 'burde', 'ache.', '', 'I', 'i', 'no', '', 'garmen', '', 'cas', 'of', 'this', 'day', 'bu', '', 'ski', 'tha', '', 'tea', 'wit', 'm', 'own', 'hands.', '', 'No', 'i', 'i', '', 'though', '', 'leav', 'behin', 'me,', 'bu', '', 'hear', 'mad', 'swee', 'wit', 'hunge', 'wit', 'thirst.', '', '*****', '', 'Ye', '', 'canno', 'tarr', 'longer.', '', 'Th', 'se', 'tha', 'call', 'al', 'thing', 'unt', 'her', 'call', 'me', '', 'mus', 'embark.', '', 'Fo', 't', 'stay', 'thoug', 'th', 'hour', 'bur', 'in', 'th', 'night', 'i', 't', 'freez', 'crystallize', 'b', 'boun', 'i', '', 'mould.', '', 'Fai', 'woul', '', 'tak', 'wit', 'm', 'al', 'tha', 'is', 'here', 'Bu', 'ho', 'shal', 'I?', '', '', 'voic', 'canno', 'carr', 'th', 'tongu', '', 'lip', 'tha', 'gav', 'i', 'wings', 'Alone', 'mus', 'i', 'see', 'th', 'ether.', '', 'alon', 'withou', 'hi', 'nes', 'shal', 'eagl', 'fl', 'acros', 'th', 'sun.', '', '*****', '', 'No', 'whe', 'h', 'reache', 'th', 'foo', 'o', 'hill', 'h', 'turne', 'agai', 'toward', 'th', 'sea,', 'h', 'sa', 'hi', 'shi', 'approachin', 'harbour', 'upo', 'he', 'pro', 'th', 'mariners,', 'th', 'me', 'o', 'hi', 'ow', 'land.', '', 'hi', 'sou', 'crie', 'ou', 't', 'them', 'he', 'said:', '', 'Son', 'o', 'm', 'ancien', 'mother', 'yo', 'rider', 'of', 'th', 'tides,', '', 'Ho', 'ofte', 'hav', 'yo', 'saile', 'i', 'm', 'dreams.', 'no', 'yo', 'com', 'i', 'm', 'awakening', 'which', 'i', 'm', 'deepe', 'dream.', '', 'Read', '', 't', 'go', 'm', 'eagernes', 'with', 'sail', 'ful', 'se', 'await', 'th', 'wind.', '', 'Onl', 'anothe', 'breat', 'wil', '', 'breath', 'in', 'thi', 'stil', 'air', 'onl', 'anothe', 'lovin', 'look', 'cas', 'backward,', '', '', 'shal', 'stan', 'amon', 'you', 'seafare', 'amon', 'seafarers', '', 'you,', 'vas', 'sea', 'sleeples', 'mother,', '', 'Wh', 'alon', 'ar', 'peac', 'freedo', 't', 'rive', 'th', 'stream,', '', 'Onl', 'anothe', 'windin', 'wil', 'thi', 'stream', 'make', 'onl', 'anothe', 'murmu', 'i', 'thi', 'glade,', '', 'shal', '', 'com', 't', 'you', 'boundles', 'dro', 't', '', 'boundles', 'ocean.', '', '*****', '', 'h', 'walke', 'h', 'sa', 'fro', 'afa', 'men', 'wome', 'leavin', 'thei', 'field', 'their', 'vineyard', 'hastenin', 'toward', 'th', 'city', 'gates.', '', 'h', 'hear', 'thei', 'voice', 'callin', 'his', 'name', 'shoutin', 'fro', 'fiel', 't', 'field', 'tellin', 'on', 'anothe', 'o', 'th', 'comin', 'o', 'his', 'ship.', '', 'h', 'sai', 't', 'himself:', '', 'Shal', 'th', 'da', 'o', 'partin', 'b', 'th', 'da', 'of', 'gathering?', '', 'shal', 'i', 'b', 'sai', 'tha', 'm', 'ev', 'wa', 'in', 'trut', 'm', 'dawn?', '', 'wha', 'shal', '', 'giv', 'unt', 'hi', 'wh', ' ...

# %% [markdown]
# # Desafío extra
#
# Reescribe la función `filtro_palabra` de arriba para que no sea sensible a mayúsculas y minúsculas. YA LO HEMOS IMPLEMENTADO

# %%
def word_filter_case(x):
   
    word_list = ['and', 'the', 'a', 'an']
    
    # your code here
    counting = sum([x.lower().count(i) for i in word_list])
    return False if counting > 0 else True

# %% [markdown]
# # Desafío 3 - Reducing
#
# #### Ahora que hemos limpiado significativamente nuestro corpus de texto, usemos la función `reduce()` para volver a unir las palabras en una cadena larga separada por espacios.
#
# Comenzaremos escribiendo una función que toma dos cadenas y las concatena juntas con un espacio entre las dos cadenas.

# %%
def concatenar_espacio(a, b):
    '''
    Entrada: Dos cadenas
    Salida: Una única cadena separada por un espacio
        
    Ejemplo:
    Entrada: 'John', 'Smith'
    Salida: 'John Smith'
    '''
    
    # tu código aquí
    return a + " " + b

# %%
# tu código aquí

# %% [markdown]
# Usa la función de arriba para reducir el corpus de texto en la lista `prophet_filter` a una única cadena. Asigna esta nueva cadena a la variable `prophet_string`.

# %%
# tu código aquí
prophet_string=reduce(concatenar_espacio,prophet_filter)
print(prophet_string)
# Out:
